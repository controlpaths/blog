# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

# %%
# Filter characteristics.
numTaps = 33
fSample = 96e3
fNyquist = fSample/2
fc = 1000

wc = fc/fNyquist

taps = signal.firwin(numTaps,wc, window='boxcar')
print(wc)
# Out:
# 0.020833333333333332

# %%
plt.plot(taps)

# %%
# Quantify taps
nBits = 24
nBitsFrac = 23
tapsQ = np.floor(taps * 2**nBitsFrac) / 2**nBitsFrac
print(tapsQ)
sum(tapsQ)
# Out:
# [0.02673149 0.02737582 0.02798665 0.02856243 0.02910161 0.02960277
#  0.03006494 0.03048658 0.03086686 0.0312047  0.03149927 0.03174984
#  0.03195572 0.03211641 0.03223145 0.03230059 0.03232372 0.03230059
#  0.03223145 0.03211641 0.03195572 0.03174984 0.03149927 0.0312047
#  0.03086686 0.03048658 0.03006494 0.02960277 0.02910161 0.02856243
#  0.02798665 0.02737582 0.02673149]
# 0.9999979734420776

# %%
x = np.ones(numTaps)
x_filt = signal.lfilter(tapsQ,1,x)
plt.plot(x_filt)
print(np.floor(x_filt*1000))
# Out:
# [ 26.  54.  82. 110. 139. 169. 199. 229. 260. 291. 323. 355. 387. 419.
#  451. 483. 516. 548. 580. 612. 644. 676. 708. 739. 770. 800. 830. 860.
#  889. 917. 945. 973. 999.]

# %%
w,h = signal.freqz(taps)
wQ,hQ = signal.freqz(tapsQ)
plt.plot(w/np.pi*fNyquist, 20 * np.log10(abs(h)), label='real')
plt.plot(wQ/np.pi*fNyquist, 20 * np.log10(abs(hQ)), label='quantized')
plt.xlim(0,8000)
#plt.ylim(-8,1)
plt.legend()
plt.grid()

# %%
# instantiation template

for i in range (0, numTaps):
    if (taps[i] >= 0):
        print(".b"+str(i)+"("+str(nBits)+"'d"+str(int(taps[i]*2**nBitsFrac))+"),")
    else:
        print(".b"+str(i)+"(-"+str(nBits)+"'d"+str(int(abs(taps[i])*2**nBitsFrac))+"),")
# Out:
# .b0(24'd224240),
# .b1(24'd229645),
# .b2(24'd234769),
# .b3(24'd239599),
# .b4(24'd244122),
# .b5(24'd248326),
# .b6(24'd252203),
# .b7(24'd255740),
# .b8(24'd258930),
# .b9(24'd261764),
# .b10(24'd264235),
# .b11(24'd266337),
# .b12(24'd268064),
# .b13(24'd269412),
# .b14(24'd270377),
# .b15(24'd270957),
# .b16(24'd271151),
# .b17(24'd270957),
# .b18(24'd270377),
# .b19(24'd269412),
# .b20(24'd268064),
# .b21(24'd266337),
# .b22(24'd264235),
# .b23(24'd261764),
# .b24(24'd258930),
# .b25(24'd255740),
# .b26(24'd252203),
# .b27(24'd248326),
# .b28(24'd244122),
# .b29(24'd239599),
# .b30(24'd234769),
# .b31(24'd229645),
# .b32(24'd224240),
