# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

# %%
nSamples = 128;
angle = np.linspace(0,2*np.pi,nSamples, endpoint=False)
sineSignal = np.sin(angle)
plt.stem(sineSignal, use_line_collection='true')
# Out:
# <StemContainer object of 3 artists>

# %%
nBits = 24
signalQuantified = (sineSignal*2**nBits)+2**(nBits-1)

# %%
# creating the file 
f = open("sine24bits_128samples.mem", "w")
for i in signalQuantified:
    f.write(format(int(signal_to_write),'x') + ' ')

f.close()
